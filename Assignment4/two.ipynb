# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('datasets_56097_107686_headbrain.csv')
data
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
w0=[1,1,1,1,1,1.5,1.5,1.5,1.5,1,1,1,1,1,1]
w1=[1,1,1,1.5,1,1.5,1,1,1,1.5,1.5,1,3,1.5,1.5]
w2=[1,1.5,1,1,1,1,1.5,1,1,1.5,1,1.5,3,1.5,3]
w3=[1,1,1,1,1.5,1,1,1.5,1,1,1.5,1,3,3,1.5]

# %%
e=[]
for i in range(0,15):
    ypre=[]
    for a in range(0,len(data['Gender'])):
        x1,x2,x3 = data['Gender'][a],data['Age Range'][a],data['Head Size(cm^3)'][a]
        ypre.append(w0[i]+w1[i]*x1+w2[i]*x2+w3[i]*x3)
    j=0
    for y in data['Brain Weight(grams)']:
        ypre[j]=y-ypre[j]
        ypre[j]=ypre[j]**2
        j+=1
    print(ypre)
    sum=0.0
    for y in ypre:
        sum+=y
    e.append(sum)
# Out:
# [8910225, 5973136, 8579041, 6240004, 6708100, 5234944, 5702544, 5322249, 5112121, 6812100, 4435236, 6843456, 5234944, 7230721, 6901129, 6120676, 4588164, 4739329, 3090564, 9162729, 6370576, 7628644, 6411024, 5968249, 9703225, 8532241, 6497401, 6451600, 4609609, 7606564, 6110784, 5602689, 7518564, 7612081, 7447441, 6812100, 4644025, 5764801, 4414201, 5040025, 6838225, 4787344, 7800849, 5004169, 6380676, 6838225, 7868025, 3814209, 5442889, 5508409, 7128900, 5982916, 8631844, 7160976, 6838225, 4999696, 6671889, 6812100, 6806881, 6007401, 6027025, 4937284, 9709456, 7683984, 5112121, 4831204, 4447881, 4937284, 8549776, 8820900, 6471936, 6110784, 7535025, 6911641, 6697744, 4853209, 5461569, 4743684, 7193124, 6370576, 6702921, 5904900, 3896676, 5456896, 6906384, 5963364, 4809249, 4796100, 4972900, 6105841, 7806436, 4536900, 5934096, 6538249, 5827396, 6853924, 5004169, 5579044, 5837056, 4892944, 5202961, 5798464, 5253264, 5499025, 5438224, 5721664, 6817321, 4739329, 6553600, 7918596, 5707321
# ...

# %%
print(e)
# Out:
# [1332786884.0, 1333642207.5, 1332786884.0, 1333572355.5, 4174607098.5, 1334130740.75, 1334200604.75, 4175595941.75, 1333345099.25, 1334427937.5, 4175999342.5, 1333642207.5, 22210742328.0, 22190621917.5, 4182059986.5]

# %%
index=[i+1 for i in range(0,15)]
x_index=np.array(index)
y_error=np.array(e)

# %%
plt.plot(x_index,y_error)

# %%
x=min(e)
i=e.index(x)
m0=w0[i]
m1=w1[i]
m2=w2[i]
m3=w3[i]

# %%
x1=float(input('enter Gender : '))
x2=float(input('enter Age Range : '))
x3=float(input('Head Size : '))
y=m0+m1*x1+m2*x2+m3*x3
print(y)
# Out:
# enter Gender : 1
# enter Age Range : 1
# Head Size : 3738
# 3741.0
